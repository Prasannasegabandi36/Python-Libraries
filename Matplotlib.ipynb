# %%
from matplotlib import pyplot as plt
x=[0,1,2,3,4]
y=[i**2 for i in x]
plt.plot(x,y,marker="s",mec="r",ms="10",mfc="y")

# %%
from matplotlib import pyplot as plt
import numpy as np
years=["2017","2013","2019","2020"]
cse=[56,78,90,199]
it=[23,67,80,90]
ece=[23,90,30,80]
eee=[10,20,30,40]
w=0.2
cse_bar=np.arange(len(years))
print(cse_bar)
plt.bar(cse_bar,cse,width=w,label='CSE')
plt.title("PLACEMENT COMPARIOSN")
plt.legend()
plt.show()
# Out:
# [0 1 2 3]

# %%
from matplotlib import pyplot as plt
student_performance=["Excellent","Good","Poor","Bad"]
student_values=[89,70,50,20]
plt.pie(student_values)
plt.show()

# %%
from matplotlib import pyplot as plt
student_performance=["Excellent","Good","Poor","Bad"]
student_values=[89,70,50,20]
plt.pie(student_values,labels=student_performance,startangle=180)
plt.show()

# %%
from matplotlib import pyplot as plt
student_performance=["Excellent","Good","Poor","Bad"]
student_values=[89,70,50,20]
plt.figure(figsize=(5,5))
plt.pie(student_values,labels=student_performance,startangle=0,shadow=True,colors=["blue","yellow","red","black"],explode=[0.2,0,0,0],autopct="%2.1f%%")

plt.legend(title="performance")
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=[100,200,300,400,500]
plt.plot(x,y)
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=[100,200,300,400,500]
plt.plot(x,y)
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.xticks(x,["a","b","c","d","e"])
plt.yticks(y,["0-100","100-200","200-300","300-400","400-500"])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parametric equation for a heart
t = np.linspace(0, 2*np.pi, 1000)
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

# Plot the heart symbol
plt.plot(x,y,'b')
plt.axis('equal')
plt.axis('off')  # Hide the axes
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range for x
x = np.linspace(-2, 2, 1000)

# Define the equations for the upper and lower half of the heart
upper_half = np.sqrt(1 - (np.abs(x) - 1)**2)
lower_half = -3*np.sqrt(1 - (np.abs(x)/2)**0.5)

# Plot the heart shape
plt.fill_between(x, upper_half, color='red')
plt.fill_between(x, lower_half, color='red')

# Adjust the aspect ratio and remove axes
plt.gca().set_aspect('equal', adjustable='box')
plt.axis('off')

# Show the plot
plt.show()

# %%
#scatter plot
from matplotlib import pyplot as plt
import random
x=[1,2,3,4,5,6]
y=[10,20,30,40,50,60]
plt.title('scatter plot')
random.shuffle(y)
print(x,y)
plt.scatter(x,y,color="green",linewidth=1,marker="*")
x1=[1,2,3,4,5,6]
y1=[10,20,30,40,50,60]
random.shuffle(y1)
print(x1,y1)
plt.scatter(x1,y1,color="red",linewidth=1,marker="^")
plt.show()
# Out:
# [1, 2, 3, 4, 5, 6] [20, 50, 10, 40, 60, 30]
# [1, 2, 3, 4, 5, 6] [40, 50, 10, 20, 60, 30]

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
colors=[10,40,50,70,100]
size=[30,40,80,90,120]
plt.scatter(x,y,s=size,cmap="viridis")
plt.colorbar()
plt.show()
# Out:
# C:\Users\sai kumar\AppData\Local\Temp\ipykernel_20380\2077983211.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,s=size,cmap="viridis")

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(0,10,3)
y=x*10
print(x,y)
plt.plot(x,y,ls="dashed",c="y",lw="3")
f1={'family':'cambria','color':'r','size':12}
f2={'family':'cambria','color':'b','size':12}
f3={'family':'cambria','color':'y','size':12}


plt.title("GAME",fontdict=f1)
plt.xlabel("x - values",fontdict=f2)
plt.ylabel("x Game 10",fontdict=f3)
plt.show()
# Out:
# [0 3 6 9] [ 0 30 60 90]

# %%
from matplotlib import pyplot as plt
x=[0,1,2,3,4]
y=[0,10,20,30,40]
plt.plot(x,y)
plt.grid(axis="y",lw=1,c='r',ls="dotted")
plt.show()

# %%
from matplotlib import pyplot as plt
x=[0,1,2,3,4]
y1=[50,20,30,10,40]
y2=[50,40,30,20,10]
y3=[10,20,30,40,50]
y4=[20,30,400,50,50]
plt.title("BIG TITLE")

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title("PLOT - 1")

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title("PLOT - 2")

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title("PLOT - 3")

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title("PLOT - 4")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(0,5,1)
y1=x**2
y2=x**3
plt.plot(x,y1,x,y2)
plt.legend(["SQUARE","CUBES"],loc="center")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, '*')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)
plt.title(' Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample exam scores (replace with your actual data)
scores = np.random.normal(loc=70, scale=10, size=1000)

# Approach-1:
plt.hist(scores, bins=10)

# Approach-2:
plt.hist(scores, bins=30)

# Approach-3
plt.hist(scores, bins=50)
# Out:
# (array([ 2.,  0.,  2.,  2.,  0.,  3.,  4.,  4.,  5., 12., 15.,  8., 17.,
#         26., 23., 19., 36., 50., 45., 35., 38., 58., 57., 46., 52., 40.,
#         47., 37., 36., 48., 34., 36., 24., 34., 30., 10., 15., 15., 10.,
#          3.,  6.,  4.,  6.,  1.,  2.,  0.,  1.,  0.,  1.,  1.]),
#  array([ 38.94804043,  40.24567582,  41.5433112 ,  42.84094658,
#          44.13858196,  45.43621734,  46.73385272,  48.03148811,
#          49.32912349,  50.62675887,  51.92439425,  53.22202963,
#          54.51966502,  55.8173004 ,  57.11493578,  58.41257116,
#          59.71020654,  61.00784192,  62.30547731,  63.60311269,
#          64.90074807,  66.19838345,  67.49601883,  68.79365422,
#          70.0912896 ,  71.38892498,  72.68656036,  73.98419574,
#          75.28183112,  76.57946651,  77.87710189,  79.17473727,
#          80.47237265,  81.77000803,  83.06764342,  84.3652788 ,
#          85.66291418,  86.96054956,  88.25818494,  89.55582032,
# ...

# %%
from matplotlib import pyplot as plt
x=[0,1,2,3,4]
y=[i**2 for i in x]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
y = [0,1,2,3,4]
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,3,5,6,7]
plt.plot(x,y,color = 'blue',linestyle = 'dashed',linewidth = 1 ,
         marker = '^', markerfacecolor = 'red',markersize = 10,label ='data')
plt.show()

# %%
#histrogram
import matplotlib.pyplot as plt
import numpy as np
data = np.random.random(100)
plt.hist(data, bins=30)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title("Histogram")
plt.show()

# %%
#heatmap
import matplotlib.pyplot as plt
import numpy as np
data = np.random.rand(10,10)
plt.imshow(data, cmap='hot')
plt.colorbar()
plt.title('heatmap with color bar')
plt.show()

# %%
#box plot
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
data = [np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data)
plt.xlabel('group')
plt.ylabel('value')
plt.title('BOx PLot')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [1,4,9,12,25]
with plt.style.context('ggplot'):
    plt.plot(x,y)
    plt.xlabel('X-Axis')
    plt.ylabel('Y-Axis')
    plt.title('XKCD-Style-plot')
    plt.grid(True)
plt.show()

# %%
# importing libraries 
import matplotlib.pyplot as plt 
import numpy as np 

x = np.linspace(0.1, 2 * np.pi, 41) 
y = np.exp(np.sin(x)) 

plt.plot(x, y, use_line_collection = False) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       5 x = np.linspace(0.1, 2 * np.pi, 41)
#       6 y = np.exp(np.sin(x))
# ----> 8 plt.plot(x, y, use_line_collection = False)
#       9 plt.show()
#
# File c:\Users\sai kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...

# %%
import matplotlib.pyplot as plt

# List of Days
days = [1, 2, 3, 4, 5]

# No of Study Hours
Studying = [7, 8, 6, 11, 7]

# No of Playing Hours
playing = [8, 5, 7, 8, 13]

# Stackplot with X, Y, colors value
plt.stackplot(days, Studying, playing,
            colors =['r', 'c'])

# Days
plt.xlabel('Days')

# No of hours
plt.ylabel('No of Hours')

# Title of Graph
plt.title('Representation of Study and \
Playing wrt to Days')

# Displaying Graph
plt.show()
